# %%
import os
import pandas as pd

# %%
# Path to the csv's
path_data_2015 = "C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/2015.csv"
path_data_2016 = "C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/2016.csv"
path_data_2017 = "C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/2017.csv"
path_data_2018 = "C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/2018.csv"
path_data_2019 = "C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/2019.csv"
path_countries_data="C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/countries.csv"
path_years_data="C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/years.csv"
path_ctry_rgn_data="C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/country_region.csv"
path_worldmap_data="C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/data_worldmap.csv"

# %%
# Reading csv ->df
data_2015_df = pd.read_csv(path_data_2015)
data_2016_df = pd.read_csv(path_data_2016)
data_2017_df = pd.read_csv(path_data_2017)
data_2018_df = pd.read_csv(path_data_2018)
data_2019_df = pd.read_csv(path_data_2019)

countries_df=pd.read_csv(path_countries_data)
years_df=pd.read_csv(path_years_data)
ctry_rgn_df=pd.read_csv(path_ctry_rgn_data)
worldmap_data_df=pd.read_csv(path_worldmap_data)

# %%
#Add region columns to 2017,2018 and 2019 df's
data_2017_df['region']=""
data_2018_df['region']=""
data_2019_df['region']=""

# %%
# Drop the unnecessary columns from 2015,2016,2017
data_2015_df.drop(['Standard Error', 'Family'], axis=1, inplace=True)
data_2016_df.drop(['Lower Confidence Interval', 'Upper Confidence Interval','Family'], axis=1, inplace=True)
data_2017_df.drop(['Whisker.high', 'Whisker.low','Family',], axis=1, inplace=True)

# %%
#Rename the columns
data_2015_df.columns = ['country', 'region', 'rank','score','gdp',
                        'health_life_expectancy','freedom','perceptions_of_corruption',
                       'generosity','dystopia_residual']

data_2016_df.columns = ['country', 'region', 'rank','score','gdp',
                        'health_life_expectancy','freedom','perceptions_of_corruption',
                       'generosity','dystopia_residual']

data_2017_df.columns = ['country','rank','score','gdp',
                        'health_life_expectancy','freedom','generosity',
                          'perceptions_of_corruption', 'dystopia_residual','region']

data_2018_df.columns = ['rank','country','score','gdp','social_support',
                        'health_life_expectancy','freedom','generosity',
                          'perceptions_of_corruption','region']

data_2019_df.columns = ['rank','country','score','gdp','social_support',
                        'health_life_expectancy','freedom','generosity',
                          'perceptions_of_corruption','region']

# %%
# Rearrange columns
data_2015_df = data_2015_df[['rank','country','region','score','gdp',
                             'health_life_expectancy','freedom',
                             'perceptions_of_corruption','generosity','dystopia_residual']]

data_2016_df = data_2016_df[['rank','country','region','score','gdp',
                             'health_life_expectancy','freedom',
                             'perceptions_of_corruption','generosity','dystopia_residual']]

data_2017_df = data_2017_df[['rank','country','region','score','gdp',
                             'health_life_expectancy','freedom',
                             'perceptions_of_corruption','generosity','dystopia_residual']]

data_2018_df = data_2018_df[['rank','country','region','score','gdp',
                             'health_life_expectancy','freedom',
                             'perceptions_of_corruption','generosity','social_support']]

data_2019_df = data_2019_df[['rank','country','region','score','gdp',
                             'health_life_expectancy','freedom',
                             'perceptions_of_corruption','generosity','social_support']]

# %%
data_2015_df.head()
data_2016_df.head()
data_2017_df.head()
data_2018_df.head()
data_2019_df.head()
# Out:
#    rank      country region  score    gdp  health_life_expectancy  freedom  \
# 0     1      Finland         7.769  1.340                   0.986    0.596
# 1     2      Denmark         7.600  1.383                   0.996    0.592
# 2     3       Norway         7.554  1.488                   1.028    0.603
# 3     4      Iceland         7.494  1.380                   1.026    0.591
# 4     5  Netherlands         7.488  1.396                   0.999    0.557
#
#    perceptions_of_corruption  generosity  social_support
# 0                      0.393       0.153           1.587
# 1                      0.410       0.252           1.573
# 2                      0.341       0.271           1.582
# 3                      0.118       0.354           1.624
# 4                      0.298       0.322           1.522

# %%
ctry_rgn_df.head()
# Out:
#        country                           region
# 0  Afghanistan                    Southern Asia
# 1      Albania       Central and Eastern Europe
# 2      Algeria  Middle East and Northern Africa
# 3       Angola               Sub-Saharan Africa
# 4    Argentina      Latin America and Caribbean

# %%
# Populating Region column to 2017,2018 and 2019 df
ctry_rgn_dict = dict()
for index,row in ctry_rgn_df.iterrows() :
    country_name = row['country']
    region = row['region']
    ctry_rgn_dict[country_name] = region
ctry_rgn_dict
# Out:
# {'Afghanistan': 'Southern Asia',
#  'Albania': 'Central and Eastern Europe',
#  'Algeria': 'Middle East and Northern Africa',
#  'Angola': 'Sub-Saharan Africa',
#  'Argentina': 'Latin America and Caribbean',
#  'Armenia': 'Central and Eastern Europe',
#  'Australia': 'Australia and New Zealand',
#  'Austria': 'Western Europe',
#  'Azerbaijan': 'Central and Eastern Europe',
#  'Bahrain': 'Middle East and Northern Africa',
#  'Bangladesh': 'Southern Asia',
#  'Belarus': 'Central and Eastern Europe',
#  'Belgium': 'Western Europe',
#  'Belize': 'Latin America and Caribbean',
#  'Benin': 'Sub-Saharan Africa',
#  'Bhutan': 'Southern Asia',
#  'Bolivia': 'Latin America and Caribbean',
#  'Bosnia and Herzegovina': 'Central and Eastern Europe',
#  'Botswana': 'Sub-Saharan Africa',
#  'Brazil': 'Latin America and Caribbean',
#  'Bulgaria': 'Central and Eastern Europe',
#  'Burkina Faso': 'Sub-Saharan Africa',
#  'Burundi': 'Sub-Saharan Africa',
#  'Cambodia': 'Southeastern Asia',
# ...

# %%
# Function to populate region 2017,2018 and 2019 df
def add_region(df):
    for index,row in df.iterrows() :
        try:
            df.loc[index,'region'] = ctry_rgn_dict.get(row['country'])
        except:
            continue

# %%
# Function call to populate the region 2017,2018 and 2019 df
add_region(data_2017_df)
add_region(data_2018_df)
add_region(data_2019_df)

# %%
data_2015_df.head()
data_2016_df.head()
data_2017_df.head()
data_2018_df.head()
data_2019_df.head()
# Out:
#    rank      country          region  score    gdp  health_life_expectancy  \
# 0     1      Finland  Western Europe  7.769  1.340                   0.986
# 1     2      Denmark  Western Europe  7.600  1.383                   0.996
# 2     3       Norway  Western Europe  7.554  1.488                   1.028
# 3     4      Iceland  Western Europe  7.494  1.380                   1.026
# 4     5  Netherlands  Western Europe  7.488  1.396                   0.999
#
#    freedom  perceptions_of_corruption  generosity  social_support
# 0    0.596                      0.393       0.153           1.587
# 1    0.592                      0.410       0.252           1.573
# 2    0.603                      0.341       0.271           1.582
# 3    0.591                      0.118       0.354           1.624
# 4    0.557                      0.298       0.322           1.522

# %%
data_2015_df.to_csv("C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data15.csv",index=False,header=True,encoding='utf-8-sig')
data_2016_df.to_csv("C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data16.csv",index=False,header=True,encoding='utf-8-sig')
data_2017_df.to_csv("C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data17.csv",index=False,header=True,encoding='utf-8-sig')
data_2018_df.to_csv("C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data18.csv",index=False,header=True,encoding='utf-8-sig')
data_2019_df.to_csv("C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data19.csv",index=False,header=True,encoding='utf-8-sig')

# %%
import pandas as pd
import pymongo
import json
import os
 
mng_client = pymongo.MongoClient('localhost', 27017)
mng_db = mng_client['project2_db']

# Import 2015 data to mongodb
collection_name='2015_data'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('/Resources/cleansed_data/clean_data15.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)

# Import 2017 data to mongodb
collection_name='2016_data'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data16.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)

# Import 2015 data to mongodb
collection_name='2017_data'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data17.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)

# Import 2015 data to mongodb
collection_name='2018_data'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data18.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)

# Import 2015 data to mongodb
collection_name='2019_data'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/cleansed_data/clean_data19.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)


# Import 2016 data to mongodb
collection_name='countries'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/countries.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)


# Import 2016 data to mongodb
collection_name='years'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/years.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)


# Import 2016 data to mongodb
collection_name='worldmap_data'
db_cm = mng_db[collection_name]
# file_res = os.path.join('Resources/clean_data15.csv')
data = pd.read_csv('C:/Users/irais/OneDrive/Desktop/Homework/Project 2_repo/Project2/Project2/Resources/raw_data/data_worldmap.csv')
data_json = json.loads(data.to_json(orient='records')) 
db_cm.remove()
db_cm.insert(data_json)
# Out:
# C:\Users\irais\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   from ipykernel import kernelapp as app
# C:\Users\irais\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   app.launch_new_instance()
# C:\Users\irais\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
# C:\Users\irais\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# C:\Users\irais\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
# C:\Users\irais\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# ...
